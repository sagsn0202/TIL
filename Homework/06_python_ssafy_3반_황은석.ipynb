# %%
# compiled-in module names
import sys

sys.builtin_module_names
# Out:
# ('_ast',
#  '_bisect',
#  '_blake2',
#  '_codecs',
#  '_codecs_cn',
#  '_codecs_hk',
#  '_codecs_iso2022',
#  '_codecs_jp',
#  '_codecs_kr',
#  '_codecs_tw',
#  '_collections',
#  '_csv',
#  '_datetime',
#  '_functools',
#  '_heapq',
#  '_imp',
#  '_io',
#  '_json',
#  '_locale',
#  '_lsprof',
#  '_md5',
#  '_multibytecodec',
#  '_opcode',
#  '_operator',
#  '_pickle',
#  '_random',
#  '_sha1',
#  '_sha256',
#  '_sha3',
#  '_sha512',
#  '_signal',
#  '_sre',
#  '_stat',
#  '_string',
#  '_struct',
#  '_symtable',
#  '_thread',
#  '_tracemalloc',
#  '_warnings',
#  '_weakref',
#  '_winapi',
#  'array',
#  'atexit',
#  'audioop',
#  'binascii',
#  'builtins',
#  'cmath',
#  'errno',
#  'faulthandler',
#  'gc',
#  'itertools',
#  'marshal',
#  'math',
#  'mmap',
#  'msvcrt',
#  'nt',
#  'parser',
#  'sys',
#  'time',
#  'winreg',
#  'xxsubtype',
#  'zipimport',
#  'zlib')

# %%
# all importable modules
# http://code.i-harness.com/ko/docs/python~3.6/library/pkgutil
import pkgutil

pkgutil.iter_modules()
# Out:
# <generator object iter_modules at 0x000001D7EC149780>

# %%
# list of all modules
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# IPython             brain_argparse      http                reprlib
# __future__          brain_attrs         idlelib             request
# _ast                brain_builtin_inference idna                requests
# _ast27              brain_collections   imaplib             rise
# _ast3               brain_curses        imghdr              rlcompleter
# _asyncio            brain_dateutil      imp                 rmagic
# _bisect             brain_fstrings      importlib           runpy
# _blake2             brain_functools     inspect             sched
# _bootlocale         brain_gi            io                  secrets
# _bz2                brain_hashlib       ipaddress           select
# _codecs             brain_io            ipykernel           selectors
# _codecs_cn          brain_mechanize     ipykernel_launcher  send2trash
# _codecs_hk          brain_multiprocessing ipython_genutils    setuptools
# _codecs_iso2022     brain_namedtuple_enum ipywidgets          shelve
# _codecs_jp          brain_nose          isort               shlex
# _codecs_kr          brain_numpy         itertools           shutil
# _codecs_tw          brain_pkg_resources jedi                signal
# _collections        brain_pytest        jinja2              site
# _collections_abc    brain_qt            json                six
# _compat_pickle      brain_random        jsonschema          smtpd
# _compression        brain_re            jupyter             smtplib
# _csv                brain_six           jupyter_client      sndhdr
# _ctypes             brain_ssl           jupyter_console     socket
# _ctypes_test        brain_subprocess    jupyter_core        socketserver
# _datetime           brain_threading     keyword             sqlite3
# _decimal            brain_typing        lazy_object_proxy   sre_compile
# _distutils_findvs   brain_uuid          lib2to3             sre_constants
# _dummy_thread       bs4                 libfuturize         sre_parse
# _elementtree        builtins            libpasteurize       ssl
# _functools          bz2                 linecache           stat
# _hashlib            cProfile            locale              statistics
# _heapq              cached              logging             storemagic
# _imp                calendar            lzma                string
# _io                 certifi             mac_icon            stringprep
# _json               cgi                 macpath             struct
# _locale             cgitb               macurl2path         subprocess
# _lsprof             chardet             mailbox             sunau
# _lzma               chunk               mailcap             symbol
# _markupbase         cmath               markupsafe          sympyprinting
# _md5                cmd                 marshal             symtable
# _msi                code                math                sys
# _multibytecodec     codecs              mccabe              sysconfig
# _multiprocessing    codeop              mimetypes           tabnanny
# _opcode             collections         mistune             tarfile
# _operator           colorama            mmap                telnetlib
# _osx_support        colorsys            modulefinder        tempfile
# _overlapped         columnate           msilib              terminado
# _pickle             compileall          msvcrt              test
# _pydecimal          concurrent          multiprocessing     testpath
# _pyio               configparser        nbconvert           tests
# _random             connection          nbformat            textwrap
# _sha1               contextlib          netrc               this
# _sha256             copy                nntplib             threading
# _sha3               copyreg             notebook            time
# _sha512             crypt               nt                  timeit
# _signal             csv                 ntpath              tkinter
# _sitebuiltins       ctypes              nturl2path          token
# _socket             curses              numbers             tokenize
# _sqlite3            cythonmagic         opcode              tornado
# _sre                darksky             operator            trace
# _ssl                datetime            optparse            traceback
# _stat               dateutil            os                  tracemalloc
# _string             dbm                 pandocfilters       traitlets
# _strptime           decimal             parser              tty
# _struct             decorator           parso               turtle
# _symtable           defusedxml          past                turtledemo
# _testbuffer         detect              pathlib             typed_ast
# _testcapi           difflib             pdb                 types
# _testconsole        dis                 pickle              typing
# _testimportmultiple distutils           pickleshare         unicodedata
# _testmultiphase     doctest             pickletools         unittest
# _thread             dummy_threading     pip                 urllib
# _threading_local    easy_install        pipes               urllib3
# _tkinter            email               pkg_resources       uu
# _tracemalloc        encodings           pkgutil             uuid
# _warnings           ensurepip           platform            venv
# _weakref            entrypoints         plistlib            warnings
# _weakrefset         enum                poplib              wave
# _winapi             errno               posixpath           wcwidth
# abc                 faulthandler        post                weakref
# aifc                filecmp             pprint              webbrowser
# antigravity         fileinput           profile             webencodings
# argparse            fnmatch             prometheus_client   webloc
# array               formatter           prompt_toolkit      widgetsnbextension
# ast                 fractions           pstats              winpty
# astroid             ftplib              pty                 winreg
# asynchat            functools           public              winsound
# asyncio             future              py_compile          wrapt
# asyncore            gc                  pyclbr              write
# atexit              genericpath         pydoc               wsgiref
# audioop             get                 pydoc_data          xdrlib
# autoreload          getopt              pyexpat             xml
# backcall            getpass             pygments            xmlrpc
# badge               gettext             pylint              xxsubtype
# base64              glob                qtconsole           zipapp
# bdb                 gzip                query_string        zipfile
# binascii            hashlib             queue               zipimport
# binhex              heapq               quopri              zlib
# bisect              hmac                random              zmq
# bleach              html                re
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
# 1
# list of built-in functions and variables
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
#  'ReferenceError',
#  'ResourceWarning',
#  'RuntimeError',
#  'RuntimeWarning',
#  'StopAsyncIteration',
#  'StopIteration',
#  'SyntaxError',
#  'SyntaxWarning',
#  'SystemError',
#  'SystemExit',
#  'TabError',
#  'TimeoutError',
#  'True',
#  'TypeError',
#  'UnboundLocalError',
#  'UnicodeDecodeError',
#  'UnicodeEncodeError',
#  'UnicodeError',
#  'UnicodeTranslateError',
#  'UnicodeWarning',
#  'UserWarning',
#  'ValueError',
#  'Warning',
#  'WindowsError',
#  'ZeroDivisionError',
#  '__IPYTHON__',
#  '__build_class__',
#  '__debug__',
#  '__doc__',
#  '__import__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'abs',
#  'all',
#  'any',
#  'ascii',
#  'bin',
#  'bool',
#  'bytearray',
#  'bytes',
#  'callable',
#  'chr',
#  'classmethod',
#  'compile',
#  'complex',
#  'copyright',
#  'credits',
#  'delattr',
#  'dict',
#  'dir',
#  'display',
#  'divmod',
#  'enumerate',
#  'eval',
#  'exec',
#  'filter',
#  'float',
#  'format',
#  'frozenset',
#  'get_ipython',
#  'getattr',
#  'globals',
#  'hasattr',
#  'hash',
#  'help',
#  'hex',
#  'id',
#  'input',
#  'int',
#  'isinstance',
#  'issubclass',
#  'iter',
#  'len',
#  'license',
#  'list',
#  'locals',
#  'map',
#  'max',
#  'memoryview',
#  'min',
#  'next',
#  'object',
#  'oct',
#  'open',
#  'ord',
#  'pow',
#  'print',
#  'property',
#  'range',
#  'repr',
#  'reversed',
#  'round',
#  'set',
#  'setattr',
#  'slice',
#  'sorted',
#  'staticmethod',
#  'str',
#  'sum',
#  'super',
#  'tuple',
#  'type',
#  'vars',
#  'zip']

# %% [markdown]
# 2. 다음 중 틀린 것은?
# (1) 함수는 오직 하나의 객체만 반환할 수 있어서, return a, b 처럼 쓸 수 없다.
# (2) 함수에서 return을 작성하지 않으면 None 값을 반환한다.
# (3) 함수의 인자(parameter)는 함수 선언시 설정한 값이며, 인수(argument)는 함수 호출시 넘겨주는 값이다.
# (4) 가변 인자를 설정할 때는 인자 앞에서 *을 붙이고, 이때는 함수 내에서 tuple로 처리된다.
# (5) 파이썬 활용되는 ‘스코프(scope)’ 룰에 따르면 변수에서 값을 Local scope ->
# Global scope -> Built-in scope 순으로 찾는다.
#
# Answer: (1)

# %%
# 3
def my_mul(*numbers):
    result = 1
    for number in numbers:
        result *= number
    return result

print(my_mul(6))
print(my_mul(3, 5))
# Out:
# 6
# 15
